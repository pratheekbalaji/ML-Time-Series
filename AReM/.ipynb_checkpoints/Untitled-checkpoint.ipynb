# %%
import pandas as pd
import os
import glob
from pathlib import Path
import numpy as np
import scipy.stats as stats

# %%
path = r'C:/Users/hp/Documents/Homework 3 Data/AReM/' # Path has to be set


files = [os.path.join(dir,file) for dir, dir_name, file_list in os.walk(path) for file in file_list if file.endswith('.csv') ]

# %%
df_activity = pd.DataFrame() # A data frame storing time domains features of various time series activities at different instances

# %%
df_activity
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
test_data_files = [f for f in files if 'test data' in f] # grouping test data together

# %%
train_data_files = [f for f in files if 'train data' in f] # grouping train data together

# %% [markdown]
# # Extracting Time Domain Features for Training Set

# %%
train_data_files
# Out:
# ['C:/Users/hp/Documents/Homework 3 Data/AReM/bending1\\train data\\dataset3.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/bending1\\train data\\dataset4.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/bending1\\train data\\dataset5.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/bending1\\train data\\dataset6.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/bending1\\train data\\dataset7.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/bending2\\train data\\dataset3.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/bending2\\train data\\dataset4.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/bending2\\train data\\dataset5.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/bending2\\train data\\dataset6.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/cycling\\train data\\dataset10.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/cycling\\train data\\dataset11.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/cycling\\train data\\dataset12.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/cycling\\train data\\dataset13.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/cycling\\train data\\dataset14.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/cycling\\train data\\dataset15.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/cycling\\train data\\dataset4.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/cycling\\train data\\dataset5.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/cycling\\train data\\dataset6.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/cycling\\train data\\dataset7.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/cycling\\train data\\dataset8.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/cycling\\train data\\dataset9.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/lying\\train data\\dataset10.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/lying\\train data\\dataset11.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/lying\\train data\\dataset12.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/lying\\train data\\dataset13.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/lying\\train data\\dataset14.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/lying\\train data\\dataset15.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/lying\\train data\\dataset4.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/lying\\train data\\dataset5.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/lying\\train data\\dataset6.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/lying\\train data\\dataset7.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/lying\\train data\\dataset8.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/lying\\train data\\dataset9.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/sitting\\train data\\dataset10.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/sitting\\train data\\dataset11.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/sitting\\train data\\dataset12.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/sitting\\train data\\dataset13.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/sitting\\train data\\dataset14.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/sitting\\train data\\dataset15.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/sitting\\train data\\dataset4.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/sitting\\train data\\dataset5.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/sitting\\train data\\dataset6.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/sitting\\train data\\dataset7.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/sitting\\train data\\dataset8.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/sitting\\train data\\dataset9.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/standing\\train data\\dataset10.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/standing\\train data\\dataset11.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/standing\\train data\\dataset12.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/standing\\train data\\dataset13.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/standing\\train data\\dataset14.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/standing\\train data\\dataset15.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/standing\\train data\\dataset4.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/standing\\train data\\dataset5.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/standing\\train data\\dataset6.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/standing\\train data\\dataset7.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/standing\\train data\\dataset8.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/standing\\train data\\dataset9.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/walking\\train data\\dataset10.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/walking\\train data\\dataset11.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/walking\\train data\\dataset12.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/walking\\train data\\dataset13.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/walking\\train data\\dataset14.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/walking\\train data\\dataset15.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/walking\\train data\\dataset4.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/walking\\train data\\dataset5.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/walking\\train data\\dataset6.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/walking\\train data\\dataset7.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/walking\\train data\\dataset8.csv',
#  'C:/Users/hp/Documents/Homework 3 Data/AReM/walking\\train data\\dataset9.csv']

# %% [markdown]
# # Extracting time domain features

# %%
def time_domain_feature(instances):
    '''A function that returns time domain features for a time series in the form of a dataframe'''
    df_activity = pd.DataFrame()
    
    for i in range (len(instances)):
        data = pd.read_csv(instances[i],skiprows=4, usecols = list(range(1,8))) # reading csv files individually

        for j,col in enumerate(data.columns[1:7]):
            df_activity.loc[i,'min'+'_'+str(j+1)] = data.iloc[:,j].min() # extracting minimum value
            df_activity.loc[i,'max'+'_'+str(j+1)]  = data.iloc[:,j].max() # maximum value
            df_activity.loc[i,'mean'+'_'+str(j+1)]  = data.iloc[:,j].mean() # mean
            df_activity.loc[i,'median'+'_'+str(j+1)]  = data.iloc[:,j].median() # median
            df_activity.loc[i,'std' +'_'+str(j+1)]  = data.iloc[:,j].std() # standard deviation
            df_activity.loc[i,'1st quartile'+'_'+str(j+1)] = data.iloc[:,j].quantile(0.25) #q1
            df_activity.loc[i,'3rd quartile'+'_'+str(j+1)] = data.iloc[:,j].quantile(0.75) #q3
        df_activity.loc[i,'Activity'] = data['Activity'][0]
           
    return df_activity

# %%
df_train = time_domain_feature(train_data_files)

# %%
df_train.shape
# Out:
# (69, 43)

# %%
df_test = time_domain_feature(test_data_files)

# %%
df_test.shape
# Out:
# (19, 43)

# %%
df_test.head()
# Out:
#    min_1  max_1     mean_1  median_1     std_1  1st quartile_1  \
# 0  37.25  45.00  40.624792     40.50  1.476967         39.2500
# 1  38.00  45.67  42.812812     42.50  1.435550         42.0000
# 2  12.75  51.00  24.562958     24.25  3.737514         23.1875
# 3   0.00  42.75  27.464604     28.00  3.583582         25.5000
# 4  24.25  45.00  37.177042     36.25  3.581301         34.5000
#
#    3rd quartile_1  min_2  max_2    mean_2    ...     1st quartile_5  \
# 0           42.00    0.0   1.30  0.358604    ...              33.00
# 1           43.67    0.0   1.22  0.372438    ...              32.00
# 2           26.50    0.0   6.87  0.590833    ...              20.50
# 3           30.00    0.0   7.76  0.449708    ...              15.00
# 4           40.25    0.0   8.58  2.374208    ...              17.95
#
#    3rd quartile_5  min_6  max_6    mean_6  median_6     std_6  1st quartile_6  \
# 0           36.00    0.0   1.92  0.570583      0.43  0.582915            0.00
# 1           34.50    0.0   3.11  0.571083      0.43  0.601010            0.00
# 2           27.00    0.0   4.97  0.700188      0.50  0.693720            0.43
# 3           20.75    0.0   6.76  1.122125      0.83  1.012342            0.47
# 4           21.75    0.0   9.34  2.921729      2.50  1.852600            1.50
#
#    3rd quartile_6  Activity
# 0            1.30  Bending1
# 1            1.30  Bending1
# 2            0.87  Bending2
# 3            1.30  Bending2
# 4            3.90   Cycling
#
# [5 rows x 43 columns]

# %%
df_all = pd.concat([df_train,df_test],axis =0)

# %%
df_all.shape
# Out:
# (88, 43)

# %%
df_all.index+=1 # Making sure indexes start from 1

# %%
df_all.reset_index(inplace =True)

# %%
df_all.rename(columns ={"index":"Instance"},inplace=True) # Creating Instance column as specified

# %%
df_all.head()
# Out:
#    Instance  min_1  max_1     mean_1  median_1     std_1  1st quartile_1  \
# 0         1  35.00  47.40  43.954500     44.33  1.558835           43.00
# 1         2  33.00  47.75  42.179813     43.50  3.670666           39.15
# 2         3  33.00  45.75  41.678063     41.75  2.243490           41.33
# 3         4  37.00  48.00  43.454958     43.25  1.386098           42.50
# 4         5  36.25  48.00  43.969125     44.50  1.618364           43.31
#
#    3rd quartile_1  min_2  max_2    ...     1st quartile_5  3rd quartile_5  \
# 0           45.00    0.0   1.70    ...            35.3625           36.50
# 1           45.00    0.0   3.00    ...            30.4575           36.33
# 2           42.75    0.0   2.83    ...            28.4575           31.25
# 3           45.00    0.0   1.58    ...            22.2500           24.00
# 4           44.67    0.0   1.50    ...            20.5000           23.75
#
#    min_6  max_6    mean_6  median_6     std_6  1st quartile_6  3rd quartile_6  \
# 0    0.0   1.79  0.493292      0.43  0.513506            0.00            0.94
# 1    0.0   2.18  0.613521      0.50  0.524317            0.00            1.00
# 2    0.0   1.79  0.383292      0.43  0.389164            0.00            0.50
# 3    0.0   5.26  0.679646      0.50  0.622534            0.43            0.87
# 4    0.0   2.96  0.555313      0.49  0.487826            0.00            0.83
#
#    Activity
# 0  Bending1
# 1  Bending1
# 2  Bending1
# 3  Bending1
# 4  Bending1
#
# [5 rows x 44 columns]

# %% [markdown]
# # ESTIMATING STANDARD DEVIATION FOR TIME DOMAIN FEATURES AND ITS 90% CONFIDENCE INTERVAL

# %%
def estimated_standard_deviation(feature):
    ''' A function which bootstraps a time domain feature in the dataset, estimates it's standard deviation and returns the 90%
     confidence interval of the estimated value
    '''
    est_std_deviation =[] # list to store estimated standard deviation for the time domain feature 1000 times
    
    for i in range(1000):
        np.random.seed(42) # setting seed
        sample = np.random.choice(df_all[feature],size =len(df_all[feature])) # resampling in order to create a bootstrap of sample size 1000
        standard_deviation = np.std(sample) # calculating it's standard deviation
        est_std_deviation.append (standard_deviation) # appending the estimated value to a list 
    std_deviation = np.mean(est_std_deviation) # in order to calculate the estimated standard deviation of the population we take the average of all values in the list
    bootstraped_ci =stats.scoreatpercentile(est_std_deviation,[5,95]) # calculating 90% confidence interval of estimated SD
    return bootstraped_ci,std_deviation

# %%
standard_deviation = [] # list to store estimated standard deviation for different time domain features in the dataset
confidence_interval = [] # list to store 90% CI of each estimated value
for features in df_all.columns[1:-1]: # iterating through the required features
    (bootstraped_ci,std_deviation) = estimated_standard_deviation(features) # invoking the function to calculate estimated SD and CI
    standard_deviation.append((features,std_deviation)) 
    confidence_interval.append(bootstraped_ci)

# %%
standard_deviation
# Out:
# [('min_1', 9.027495991929188),
#  ('max_1', 3.6628076197216406),
#  ('mean_1', 5.220156454429949),
#  ('median_1', 5.506726983249914),
#  ('std_1', 1.6335086072282619),
#  ('1st quartile_1', 6.1187536531616065),
#  ('3rd quartile_1', 4.941631168749297),
#  ('min_2', 0.0),
#  ('max_2', 4.982491606721853),
#  ('mean_2', 1.638574125349916),
#  ('median_2', 1.4721746648416596),
#  ('std_2', 0.8915932008987454),
#  ('1st quartile_2', 1.0078868830260572),
#  ('3rd quartile_2', 2.203743570296858),
#  ('min_3', 2.9097059275312924),
#  ('max_3', 4.119629837740277),
#  ('mean_3', 3.385150222513438),
#  ('median_3', 3.5088126099421526),
#  ('std_3', 0.8952053375646738),
#  ('1st quartile_3', 3.5526399871221366),
#  ('3rd quartile_3', 3.5384235671944086),
#  ('min_4', 0.0),
#  ('max_4', 2.0274376684582616),
#  ('mean_4', 1.1677848414812682),
#  ('median_4', 1.1619389030679756),
#  ('std_4', 0.41209332828370226),
#  ('1st quartile_4', 0.8616641862169304),
#  ('3rd quartile_4', 1.5594099517439732),
#  ('min_5', 5.967262676531273),
#  ('max_5', 5.93682599045223),
#  ('mean_5', 5.819122851404928),
#  ('median_5', 6.080609595695862),
#  ('std_5', 0.9701980686875726),
#  ('1st quartile_5', 6.026292665716783),
#  ('3rd quartile_5', 5.792398261564656),
#  ('min_6', 0.04557696582759307),
#  ('max_6', 2.54696501450726),
#  ('mean_6', 1.1714646314423462),
#  ('median_6', 1.1110454888902002),
#  ('std_6', 0.5170225703349993),
#  ('1st quartile_6', 0.7744846056010515),
#  ('3rd quartile_6', 1.5576376119844422)]

# %%
standard_deviation_values = [x[1] for x in standard_deviation] # storing the values of estimated standard deviation in a list
standard_deviation_index = [x[0] for x in standard_deviation]  # stroring the feature names

# %% [markdown]
# # Creating a DataFrame to display the estimated SD and corresponding confidence interval

# %%
df_estimated_deviation = pd.DataFrame(list(zip(standard_deviation_values, confidence_interval)),index = standard_deviation_index , columns =['Standard Deviation','90%CI'])

# %%
df_estimated_deviation
# Out:
#                 Standard Deviation  \
# min_1                     9.027496
# max_1                     3.662808
# mean_1                    5.220156
# median_1                  5.506727
# std_1                     1.633509
# 1st quartile_1            6.118754
# 3rd quartile_1            4.941631
# min_2                     0.000000
# max_2                     4.982492
# mean_2                    1.638574
# median_2                  1.472175
# std_2                     0.891593
# 1st quartile_2            1.007887
# 3rd quartile_2            2.203744
# min_3                     2.909706
# max_3                     4.119630
# mean_3                    3.385150
# median_3                  3.508813
# std_3                     0.895205
# 1st quartile_3            3.552640
# 3rd quartile_3            3.538424
# min_4                     0.000000
# max_4                     2.027438
# mean_4                    1.167785
# median_4                  1.161939
# std_4                     0.412093
# 1st quartile_4            0.861664
# 3rd quartile_4            1.559410
# min_5                     5.967263
# max_5                     5.936826
# mean_5                    5.819123
# median_5                  6.080610
# std_5                     0.970198
# 1st quartile_5            6.026293
# 3rd quartile_5            5.792398
# min_6                     0.045577
# max_6                     2.546965
# mean_6                    1.171465
# median_6                  1.111045
# std_6                     0.517023
# 1st quartile_6            0.774485
# 3rd quartile_6            1.557638
#
#                                                        90%CI
# min_1                 [9.027495991929188, 9.027495991929188]
# max_1                   [3.66280761972164, 3.66280761972164]
# mean_1                [5.220156454429948, 5.220156454429948]
# median_1              [5.506726983249913, 5.506726983249913]
# std_1               [1.6335086072282623, 1.6335086072282623]
# 1st quartile_1      [6.1187536531616065, 6.1187536531616065]
# 3rd quartile_1        [4.941631168749297, 4.941631168749297]
# min_2                                             [0.0, 0.0]
# max_2                 [4.982491606721854, 4.982491606721854]
# mean_2                [1.638574125349916, 1.638574125349916]
# median_2            [1.4721746648416598, 1.4721746648416598]
# std_2               [0.8915932008987458, 0.8915932008987458]
# 1st quartile_2      [1.0078868830260574, 1.0078868830260574]
# 3rd quartile_2        [2.203743570296858, 2.203743570296858]
# min_3               [2.9097059275312933, 2.9097059275312933]
# max_3                 [4.119629837740279, 4.119629837740279]
# mean_3              [3.3851502225134364, 3.3851502225134364]
# median_3            [3.5088126099421513, 3.5088126099421513]
# std_3               [0.8952053375646734, 0.8952053375646734]
# 1st quartile_3      [3.5526399871221366, 3.5526399871221366]
# 3rd quartile_3        [3.538423567194409, 3.538423567194409]
# min_4                                             [0.0, 0.0]
# max_4               [2.0274376684582616, 2.0274376684582616]
# mean_4              [1.1677848414812684, 1.1677848414812684]
# median_4            [1.1619389030679754, 1.1619389030679754]
# std_4               [0.4120933282837024, 0.4120933282837024]
# 1st quartile_4      [0.8616641862169301, 0.8616641862169301]
# 3rd quartile_4      [1.5594099517439732, 1.5594099517439732]
# min_5                 [5.967262676531271, 5.967262676531271]
# max_5                 [5.936825990452229, 5.936825990452229]
# mean_5                  [5.81912285140493, 5.81912285140493]
# median_5             [6.080609595695862, 6.0806095956958615]
# std_5               [0.9701980686875725, 0.9701980686875725]
# 1st quartile_5        [6.026292665716785, 6.026292665716785]
# 3rd quartile_5        [5.792398261564653, 5.792398261564655]
# min_6           [0.045576965827593074, 0.045576965827593074]
# max_6                   [2.54696501450726, 2.54696501450726]
# mean_6                [1.171464631442346, 1.171464631442346]
# median_6            [1.1110454888902004, 1.1110454888902004]
# std_6               [0.5170225703349991, 0.5170225703349991]
# 1st quartile_6      [0.7744846056010517, 0.7744846056010517]
# 3rd quartile_6        [1.557637611984442, 1.557637611984442]

# %% [markdown]
# # Selecting the 3 most important features from DataFrame

# %% [markdown]
# # Selecting Min, Mean and Max

# %%
imp_features = ['min','mean','max']

# %% [markdown]
# # Selecting the important features from train data

# %%
df_train.head()
# Out:
#    min_1  max_1     mean_1  median_1     std_1  1st quartile_1  \
# 0  35.00  47.40  43.954500     44.33  1.558835           43.00
# 1  33.00  47.75  42.179813     43.50  3.670666           39.15
# 2  33.00  45.75  41.678063     41.75  2.243490           41.33
# 3  37.00  48.00  43.454958     43.25  1.386098           42.50
# 4  36.25  48.00  43.969125     44.50  1.618364           43.31
#
#    3rd quartile_1  min_2  max_2    mean_2    ...     1st quartile_5  \
# 0           45.00    0.0   1.70  0.426250    ...            35.3625
# 1           45.00    0.0   3.00  0.696042    ...            30.4575
# 2           42.75    0.0   2.83  0.535979    ...            28.4575
# 3           45.00    0.0   1.58  0.378083    ...            22.2500
# 4           44.67    0.0   1.50  0.413125    ...            20.5000
#
#    3rd quartile_5  min_6  max_6    mean_6  median_6     std_6  1st quartile_6  \
# 0           36.50    0.0   1.79  0.493292      0.43  0.513506            0.00
# 1           36.33    0.0   2.18  0.613521      0.50  0.524317            0.00
# 2           31.25    0.0   1.79  0.383292      0.43  0.389164            0.00
# 3           24.00    0.0   5.26  0.679646      0.50  0.622534            0.43
# 4           23.75    0.0   2.96  0.555313      0.49  0.487826            0.00
#
#    3rd quartile_6  Activity
# 0            0.94  Bending1
# 1            1.00  Bending1
# 2            0.50  Bending1
# 3            0.87  Bending1
# 4            0.83  Bending1
#
# [5 rows x 43 columns]

# %%
imp_cols= [cols for cols in df_train.columns.values if any (imp in cols for imp in imp_features)]

# %%
imp_cols
# Out:
# ['min_1',
#  'max_1',
#  'mean_1',
#  'min_2',
#  'max_2',
#  'mean_2',
#  'min_3',
#  'max_3',
#  'mean_3',
#  'min_4',
#  'max_4',
#  'mean_4',
#  'min_5',
#  'max_5',
#  'mean_5',
#  'min_6',
#  'max_6',
#  'mean_6']

# %%
imp_cols.append('Activity')

# %%
df_train_imp = df_train[imp_cols]

# %%
df_train_imp.head()
# Out:
#    min_1  max_1     mean_1  min_2  max_2    mean_2  min_3  max_3     mean_3  \
# 0  35.00  47.40  43.954500    0.0   1.70  0.426250   6.50  29.75  22.122354
# 1  33.00  47.75  42.179813    0.0   3.00  0.696042   8.50  30.00  22.183625
# 2  33.00  45.75  41.678063    0.0   2.83  0.535979   3.00  28.25  19.006562
# 3  37.00  48.00  43.454958    0.0   1.58  0.378083   5.75  27.00  15.793333
# 4  36.25  48.00  43.969125    0.0   1.50  0.413125   1.50  26.33  15.868021
#
#    min_4  max_4    mean_4  min_5  max_5     mean_5  min_6  max_6    mean_6  \
# 0    0.0   4.44  0.497313  29.00  38.50  35.588458    0.0   1.79  0.493292
# 1    0.0   5.15  0.989917  20.00  38.67  33.493917    0.0   2.18  0.613521
# 2    0.0   6.42  0.841875  23.67  37.50  29.857083    0.0   1.79  0.383292
# 3    0.0  10.03  0.849354   8.00  33.50  23.034792    0.0   5.26  0.679646
# 4    0.0   5.17  0.666354  11.33  30.75  22.103750    0.0   2.96  0.555313
#
#    Activity
# 0  Bending1
# 1  Bending1
# 2  Bending1
# 3  Bending1
# 4  Bending1

# %%
df_train_imp['Activity'] =  df_train_imp['Activity'].apply(lambda x : 1  if x=='Bending1' or x =='Bending2' else 0)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_train_imp.head()
# Out:
#    min_1  max_1     mean_1  min_2  max_2    mean_2  min_3  max_3     mean_3  \
# 0  35.00  47.40  43.954500    0.0   1.70  0.426250   6.50  29.75  22.122354
# 1  33.00  47.75  42.179813    0.0   3.00  0.696042   8.50  30.00  22.183625
# 2  33.00  45.75  41.678063    0.0   2.83  0.535979   3.00  28.25  19.006562
# 3  37.00  48.00  43.454958    0.0   1.58  0.378083   5.75  27.00  15.793333
# 4  36.25  48.00  43.969125    0.0   1.50  0.413125   1.50  26.33  15.868021
#
#    min_4  max_4    mean_4  min_5  max_5     mean_5  min_6  max_6    mean_6  \
# 0    0.0   4.44  0.497313  29.00  38.50  35.588458    0.0   1.79  0.493292
# 1    0.0   5.15  0.989917  20.00  38.67  33.493917    0.0   2.18  0.613521
# 2    0.0   6.42  0.841875  23.67  37.50  29.857083    0.0   1.79  0.383292
# 3    0.0  10.03  0.849354   8.00  33.50  23.034792    0.0   5.26  0.679646
# 4    0.0   5.17  0.666354  11.33  30.75  22.103750    0.0   2.96  0.555313
#
#    Activity
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1

# %% [markdown]
# #
